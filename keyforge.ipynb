# %%
from keyforge import dataframes, plots, utils
import warnings
warnings.filterwarnings("ignore")

# %%
deck_df = dataframes.deck_df()
deck_df
# Out:
#                                          name   set        house1  \
# id
# A0             The Cold Archivist of Trapoint  CotA          mars
# A1                      Miss "Onyx" Censorius  CotA       shadows
# A2                  Radiant Argus the Supreme  CotA       untamed
# A3             Amoryork of the Baker's chapel  CotA          mars
# A4          Boaros of the Supplicant's Forest  CotA       untamed
# A5        The Opalescent Number of Roundtable  CotA       untamed
# A6   H. Price, Southmount's Reasonable Zealot  CotA       sanctum
# A7             Reyes, the Tracker of Dwartown  CotA          mars
# A8       The Partisan that Unifies Agreements  CotA       shadows
# A9                                 Kite Rojas  CotA          mars
# B0                        He that Betrays Fun   AoA       shadows
# B1                Zerra "Director Slush" Higa   AoA       untamed
# B2                        The moldy misteress   AoA       untamed
# B3       Al-Battani, the Telepathist of Study   AoA       untamed
# B4                          Artemis, Moon Ape   AoA       untamed
# B5                   Vaughn “Upload” Autotean   AoA       untamed
# B6          Vhexh, Naysayer of the Awful Shop   AoA          mars
# C0               Bramble of Farhenge Alleyway    WC       untamed
# C1                   Patchery the Pessimistic    WC       untamed
# C2  Darkcreep, It that Misinterprets the Peak    WC       shadows
# C3      The Turncoat that Conceives Suffering    WC       untamed
# C4                    Adviser Breanna Bittail    WC       shadows
# C5                     Hygelac “Axe” Blazefox    WC       brobnar
# C6                 Exixia, Spawn of Flexiloud    WC       saurian
# C7    F. Jesperson, Unigus's Trivial Overlord    WC       saurian
# D0                    The Dr. of Mandigopolis    MM       untamed
# D1  Jarbuilder, the Ringleader of the Citadel    MM       saurian
# D2                   Perutz the Intensily Hot    MM       saurian
# D3  The Time-Stopper that Counterfeits Silver    MM       saurian
# D4                       Baker Bilal Javahawk    MM       untamed
# D5       The Intimidator that Insults Bubbles    MM       saurian
# E0       Jarpfoil Swindle, Deacon's Evil Twin    DT       untamed
# E1            Q. Costa of the Untidy Ballroom    DT       shadows
# E2           Jeffrys, the Writer of Sculpture    DT       saurian
# E3                    Steward Miles Jagayouth    DT       untamed
# F0              Judah "No relation" Restudusa   WoE          mars
# F1                          Ayya Q. Oniawhirl   WoE       saurian
# F2   Trunkusk Mertens, the Psychic and Untidy   WoE          mars
# F3                  Sai "Lighteater" Fishwick   WoE          mars
# G0                      The Despot of Bomsini    GR          mars
# G1                  Zipmachine, the Troll Sun    GR  unfathomable
# G2         Cambiadrop of the Daughter's Cliff    GR       untamed
# G3       Porshedevil, the Praefectus Aeronaut    GR       brobnar
# H0              Valle, Huxpines’s Scaremonger    AS           dis
# H1     Swordvian Shallows-de Toeni, Underling    AS      geistoid
# H2                     Xzx. Ipsisiege Shuurga    AS       skyborn
# H3      Rósa Fionsidh from the Hero’s Retreat    AS       ekwidon
#
#            house2         house3  SAS  entry_date
# id
# A0        brobnar        sanctum   59  2020-02-02
# A1        brobnar            dis   66  2020-02-02
# A2          logos        sanctum   65  2020-02-02
# A3        brobnar        sanctum   66  2020-02-02
# A4        brobnar            dis   63  2020-06-03
# A5          logos        sanctum   60  2020-08-29
# A6          logos            dis   66  2020-08-29
# A7        brobnar        shadows   61  2024-07-21
# A8        brobnar            dis   71  2024-07-21
# A9        shadows            dis   58  2024-07-21
# B0          logos        brobnar   56  2020-02-02
# B1           mars            dis   60  2020-02-02
# B2        brobnar        sanctum   55  2020-02-02
# B3           mars        shadows   58  2020-03-11
# B4           mars            dis   53  2020-03-11
# B5        brobnar        sanctum   52  2020-06-03
# B6          logos            dis   58  2020-07-23
# C0        shadows            dis   64  2020-02-02
# C1          logos        brobnar   49  2020-02-02
# C2          logos            dis   82  2020-02-02
# C3          logos        brobnar   70  2020-06-03
# C4  star alliance            dis   58  2020-06-03
# C5  star alliance            dis   58  2020-06-03
# C6          logos            dis   76  2020-06-21
# C7        brobnar            dis   64  2024-07-21
# D0          logos        sanctum   60  2020-08-03
# D1          logos        sanctum   66  2020-08-03
# D2  star alliance        shadows   65  2020-08-03
# D3          logos        sanctum   84  2020-08-03
# D4  star alliance        saurian   65  2020-08-03
# D5          logos            dis   65  2020-08-03
# E0        saurian   unfathomable   60  2021-05-02
# E1  star alliance        sanctum   63  2021-05-02
# E2          logos        sanctum   63  2021-05-02
# E3        shadows        sanctum   69  2021-05-02
# F0  star alliance        ekwidon   64  2023-10-25
# F1  star alliance   unfathomable   70  2023-10-25
# F2  star alliance        saurian   81  2023-10-25
# F3        ekwidon   unfathomable   77  2023-10-25
# G0        untamed  star alliance   67  2024-10-20
# G1        ekwidon        untamed   75  2024-10-20
# G2        brobnar   unfathomable   83  2024-10-20
# G3        ekwidon           mars   78  2024-10-20
# H0           mars        skyborn   75  2024-11-09
# H1        ekwidon        brobnar   87  2024-11-09
# H2            dis        brobnar   76  2024-11-09
# H3           mars            dis   63  2024-11-09

# %%
plots.plot_deck_overview(deck_df)

# %%
match_df = dataframes.match_df()
match_df
# Out:
#            date id1 id2  k1  k2  cumulative_matches  number_decks  \
# 0    2020-02-02  A3  C0   3   1                 1.0          10.0
# 1    2020-02-03  A1  A2   2   3                 2.0          10.0
# 2    2020-02-04  B1  B2   1   3                 3.0          10.0
# 3    2020-02-05  C1  C2   0   3                 4.0          10.0
# 4    2020-02-06  A0  B0   2   3                 5.0          10.0
# ..          ...  ..  ..  ..  ..                 ...           ...
# 247  2024-11-08  E1  G0   2   3               248.0          43.0
# 248  2024-11-09  A7  H0   2   3               249.0          47.0
# 249  2024-11-10  B2  H1   1   3               250.0          47.0
# 250  2024-11-13  C7  H3   3   2               251.0          47.0
# 251  2024-11-16  D3  H2   2   3               252.0          47.0
#
#      possible_matches  perc_completion
# 0                45.0              2.2
# 1                45.0              4.4
# 2                45.0              6.7
# 3                45.0              8.9
# 4                45.0             11.1
# ..                ...              ...
# 247             903.0             27.5
# 248            1081.0             23.0
# 249            1081.0             23.1
# 250            1081.0             23.2
# 251            1081.0             23.3
#
# [252 rows x 9 columns]

# %%
plots.plot_time_changes(match_df)

# %%
match_hm = dataframes.match_hm(deck_df, match_df)
plots.plot_match_results(match_hm)

# %% [markdown]
# ## Deck stats

# %%
dataframes.add_deck_stats(deck_df, match_hm)
plots.plot_deck_stats(deck_df)

# %%
plots.plot_win_vs_sas(deck_df)

# %% [markdown]
# ## House stats

# %%
house_df = dataframes.group_df(deck_df, "house")
(house_plays_hm, house_wins_hm) = dataframes.group_hms(house_df, deck_df, match_hm, "house")
plots.plot_group_heatmaps(house_df, house_plays_hm, house_wins_hm, 22)

# %%
plots.plot_house_trends(house_df)

# %% [markdown]
# ## Set stats

# %%
set_df = dataframes.group_df(deck_df, "set")
(set_plays_hm, set_wins_hm) = dataframes.group_hms(set_df, deck_df, match_hm, "set")
plots.plot_group_heatmaps(set_df, set_plays_hm, set_wins_hm, 18)

# %%
plots.plot_set_trends(set_df)

# %%
utils.find_next_game(deck_df, match_hm, set_plays_hm)
# Out:
#                              name set   house1   house2   house3  SAS  \
# id
# E3        Steward Miles Jagayouth  DT  untamed  shadows  sanctum   69
# H0  Valle, Huxpines’s Scaremonger  AS      dis     mars  skyborn   75
#
#     entry_date  plays  wins  keys_forged  key_diff  win_rate  avg_keys_forged  \
# id
# E3  2021-05-02    6.0   4.0         16.0       3.0      66.7              2.7
# H0  2024-11-09    1.0   1.0          3.0       1.0     100.0              3.0
#
#     avg_key_diff
# id
# E3           0.5
# H0           1.0
